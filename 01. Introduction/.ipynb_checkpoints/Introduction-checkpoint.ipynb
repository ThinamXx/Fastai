# %% [markdown]
# ### **INITIALIZATION:**
# - I use these three lines of code on top of my each notebooks because it will help to prevent any problems while reloading the same project. And the third line of code helps to make visualization within the notebook.

# %%
#@ INITIALIZATION: 
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# **DOWNLOADING LIBRARIES AND DEPENDENCIES:**
# - I have downloaded all the libraries and dependencies required for the project in one particular cell.

# %%
#@ INSTALLING DEPENDENCIES: UNCOMMENT BELOW: 
# !pip install -Uqq fastbook
# import fastbook
# fastbook.setup_book()

# %% [markdown]
# ### [**CAT AND DOG CLASSIFICATION**](https://github.com/fastai/fastbook/blob/master/01_intro.ipynb)
# - I will download and extract a dataset called the [**Oxford-IIIT Pet Dataset**](https://www.robots.ox.ac.uk/~vgg/data/pets/) that contains 7349 images of cats and dogs from 37 breeds from the fast.ai datasets collection to the GPU server. I will use pretrained model that has already been trained on 1.3 million images. The pretrained model will be fine tuned using the latest advances in transfer learning to create a model that is specially customized for recognizing dogs and cats.

# %%
#@ DEPENDENCIES AND DATASET: 
from fastai.vision.all import *                           # Getting all Libraries. 
PATH = untar_data(URLs.PETS)/"images"                     # Path to the Images of Pets.

# %%
#@ PREPARING THE DATASET: 
def is_cat(x):                                            # Function for Recognizing Cats. 
  return x[0].isupper()                                   # Inspecting Uppercase. 
#@ INITIALIZING DATALOADERS: 
dls = ImageDataLoaders.from_name_func(                    # Initializing Image DataLoaders. 
      PATH, get_image_files(PATH), valid_pct=0.2,         # Getting Image Files. 
      seed=42, label_func=is_cat,                         # Function for Labels. 
      item_tfms=Resize(224))                              # Resizing the Images.

# %%
#@ TRAINING THE MODEL: 
learn = cnn_learner(dls, resnet34,                        # Using Pretrained RESNET Model. 
                    metrics=error_rate)                   # Building Convolutional Model. 
learn.fine_tune(1)                                        # Training the Model.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.129782</td>
#       <td>0.024574</td>
#       <td>0.012179</td>
#       <td>00:47</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.062890</td>
#       <td>0.022565</td>
#       <td>0.005413</td>
#       <td>00:53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - The error rate is less than 0.02 as show in the result above.

# %%
#@ INSPECTING DOG IMAGE: 
PATH = "/content/Bal.JPG"                       # Path to Image. 
img = PILImage.create(PATH)                     # Initializing Image. 
img.to_thumb(224)                               # Inspecting Image.
# Out:
# <PIL.Image.Image image mode=RGB size=224x149 at 0x7FC569919BD0>

# %%
#@ MODEL EVALUATION: 
is_cat, _, probs = learn.predict(img)               # Getting Predictions. 
print(f"Is this a cat?: {is_cat}.")
print(f"Probability: {probs[1].item():.6f}")
# Out:
# Is this a cat?: False.
# Probability: 0.000368

# %% [markdown]
# ### [**SEMANTIC SEGMENTATION:**](https://github.com/fastai/fastbook/blob/master/01_intro.ipynb)
# - Creating a model that can recognize the content of every individual pixel in an image is called Segmentation.

# %%
#@ DEPENDENCIES AND DATASET:
from fastai.vision.all import *                                   # Getting all the Libraries. 
PATH = untar_data(URLs.CAMVID_TINY)                               # Path to the Dataset.

# %%
#@ INITIALIZING DATALOADERS: 
dls = SegmentationDataLoaders.from_label_func(                    # Initializing Segmentation DataLoaders. 
      PATH, bs=8, fnames=get_image_files(PATH/"images"),          # Getting Image Files.
      label_func=lambda o: PATH/"labels"/f"{o.stem}_P{o.suffix}", # Getting Labels from Dataset.  
      codes=np.loadtxt(PATH/"codes.txt", dtype=str))

# %%
#@ TRAINING THE MODEL: 
learn = unet_learner(dls, resnet34)                               # Initializing Pretrained RESNET Model. 
learn.fine_tune(4)                                                # Tuning Model for 4 Epochs.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.290693</td>
#       <td>2.505730</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.776736</td>
#       <td>1.578815</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.593198</td>
#       <td>1.321665</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.420301</td>
#       <td>1.104516</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.294482</td>
#       <td>1.067586</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
#@ INSPECTING THE MODEL PREDICTION: 
learn.show_results(max_n=4, figsize=(7, 8))                       # Inspecting Segmented Images.

# %% [markdown]
# ### **SENTIMENT CLASSIFICATION:**
# - I will create a model that can classify the sentiment of a movie review. Computers can now generate text, translate automatically from one language to another, analyze comments, label words in sentences with the advancement of deep learning in Natural Language Processing.

# %%
#@ DEPENDENCIES AND DATASET: 
from fastai.text.all import *                           # Getting all the Libraries. 
PATH = untar_data(URLs.IMDB)                            # Getting IMDB Dataset.

# %%
#@ INITIALIZING DATALOADERS: 
dls = TextDataLoaders.from_folder(PATH, valid="test")   # Initializing Text DataLoaders.

# %%
#@ TRAINING THE MODEL: 
learn = text_classifier_learner(dls, AWD_LSTM,          # Initializing Pretrained LSTM Model. 
                                metrics=accuracy)       # Initializing Accuracy. 
learn.fine_tune(2, 1e-2)                                # Tuning with Epochs and Learning Rate.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.465836</td>
#       <td>0.402111</td>
#       <td>0.819760</td>
#       <td>03:50</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.286522</td>
#       <td>0.254014</td>
#       <td>0.895880</td>
#       <td>07:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.221345</td>
#       <td>0.196227</td>
#       <td>0.922600</td>
#       <td>07:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
#@ INSPECTING MODEL PREDICTION:
learn.predict("I am bored and tired with that movie!")     # Inspecting Predictions.
# Out:
# ('neg', tensor(0), tensor([0.8389, 0.1611]))

# %% [markdown]
# ### **TABULAR CLASSIFICATION:**
# - The model will be using [**Adult**](https://archive.ics.uci.edu/ml/datasets/adult) dataset which contains some demographic data about individuals such as their education, marital status, race, sex and whether they have an annual income greater than $50k.

# %%
#@ DEPENDENCIES AND DATASET: 
from fastai.tabular.all import *                                 # Getting all the Libraries. 
PATH = untar_data(URLs.ADULT_SAMPLE)                             # Getting Path to the Dataset.

# %%
#@ INITIALIZING DATALOADERS: 
dls = TabularDataLoaders.from_csv(                               # Initializing Tabular Data Loaders. 
      PATH/"adult.csv", path=PATH, y_names="salary",             # Initializing Path and Target Column. 
      cat_names=["workclass", "education", "marital-status", 
                 "occupation", "relationship", "race"],          # Initializing Categorical Columns. 
      cont_names=["age", "fnlwgt", "education-num"],             # Initializing Continuous Columns. 
      procs=[Categorify, FillMissing, Normalize])                # Initializing Methods.

# %%
#@ TRAINING THE MODEL: 
learn = tabular_learner(dls, metrics=accuracy)                   # Initializing the Model. 
learn.fit_one_cycle(3)                                           # Training the Model.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.386055</td>
#       <td>0.367954</td>
#       <td>0.827856</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.364823</td>
#       <td>0.356083</td>
#       <td>0.832463</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.356137</td>
#       <td>0.350183</td>
#       <td>0.837531</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **RECOMMENDATION SYSTEM MODEL:**
# - I will train a model that will predict movies people might like based on their previous viewing habits using [**MovieLens Dataset**](https://dl.acm.org/doi/10.1145/2827872).

# %%
#@ DEPENDENCIES AND DATASET: 
from fastai.collab import *                                   # Getting all the Libraries. 
PATH = untar_data(URLs.ML_SAMPLE)                             # Getting Path to the Dataset.

# %%
#@ INITIALIZING DATALOADERS: 
dls = CollabDataLoaders.from_csv(PATH/"ratings.csv")          # Initializing Collaborative DataLoaders.

# %%
#@ TRAINING THE MODEL: 
learn = collab_learner(dls, y_range=(0.5, 5.5))               # Initializing the Model with Target Range. 
learn.fine_tune(10)                                           # Training the Model for 10 Epochs.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.472650</td>
#       <td>1.466208</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.364758</td>
#       <td>1.407162</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.256032</td>
#       <td>1.226296</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.021405</td>
#       <td>0.917358</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.791084</td>
#       <td>0.770485</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.676592</td>
#       <td>0.737836</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.630821</td>
#       <td>0.727034</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.616012</td>
#       <td>0.723062</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.600870</td>
#       <td>0.720729</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.606827</td>
#       <td>0.719909</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.597705</td>
#       <td>0.719838</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
#@ INSPECTING MODEL PREDICTION: 
learn.show_results()                                             # Inspecting the Predictions.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>movieId</th>
#       <th>rating</th>
#       <th>rating_pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>69.0</td>
#       <td>16.0</td>
#       <td>5.0</td>
#       <td>4.570286</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>19.0</td>
#       <td>54.0</td>
#       <td>4.5</td>
#       <td>4.197601</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>43.0</td>
#       <td>26.0</td>
#       <td>4.0</td>
#       <td>3.691482</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>66.0</td>
#       <td>89.0</td>
#       <td>5.0</td>
#       <td>4.027447</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>21.0</td>
#       <td>88.0</td>
#       <td>4.5</td>
#       <td>3.796919</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>68.0</td>
#       <td>26.0</td>
#       <td>4.0</td>
#       <td>3.863594</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>92.0</td>
#       <td>93.0</td>
#       <td>4.5</td>
#       <td>4.250734</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>14.0</td>
#       <td>63.0</td>
#       <td>4.0</td>
#       <td>3.952862</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>86.0</td>
#       <td>95.0</td>
#       <td>4.0</td>
#       <td>3.843777</td>
#     </tr>
#   </tbody>
# </table>
